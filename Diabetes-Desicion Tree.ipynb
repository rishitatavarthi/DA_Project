# %%
import pandas as pd

# %%
df=pd.read_csv('/content/diabetcsv (1).csv')

# %%
df
# Out:
#      preg  plas  pres  skin  insu  mass   pedi  age            class
# 0       6   148    72    35     0  33.6  0.627   50  tested_positive
# 1       1    85    66    29     0  26.6  0.351   31  tested_negative
# 2       8   183    64     0     0  23.3  0.672   32  tested_positive
# 3       1    89    66    23    94  28.1  0.167   21  tested_negative
# 4       0   137    40    35   168  43.1  2.288   33  tested_positive
# ..    ...   ...   ...   ...   ...   ...    ...  ...              ...
# 763    10   101    76    48   180  32.9  0.171   63  tested_negative
# 764     2   122    70    27     0  36.8  0.340   27  tested_negative
# 765     5   121    72    23   112  26.2  0.245   30  tested_negative
# 766     1   126    60     0     0  30.1  0.349   47  tested_positive
# 767     1    93    70    31     0  30.4  0.315   23  tested_negative
#
# [768 rows x 9 columns]

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
target=df["class"]
print(target)
# Out:
# 0      tested_positive
# 1      tested_negative
# 2      tested_positive
# 3      tested_negative
# 4      tested_positive
#             ...
# 763    tested_negative
# 764    tested_negative
# 765    tested_negative
# 766    tested_positive
# 767    tested_negative
# Name: class, Length: 768, dtype: object

# %%
feat_list=['insu','mass','age']
feat=df[feat_list]
print(feat)
# Out:
#      insu  mass  age
# 0       0  33.6   50
# 1       0  26.6   31
# 2       0  23.3   32
# 3      94  28.1   21
# 4     168  43.1   33
# ..    ...   ...  ...
# 763   180  32.9   63
# 764     0  36.8   27
# 765   112  26.2   30
# 766     0  30.1   47
# 767     0  30.4   23
#
# [768 rows x 3 columns]

# %%
model=DecisionTreeClassifier()
model.fit(feat,target)
# Out:
# DecisionTreeClassifier()

# %%
DT=model.fit(feat,target)

# %%
insu=int(input("Enter Insulin: "))
mass=int(input("Enter Mass: "))
age=int(input("Enter Age: "))
pred=model.predict([[insu,mass,age]])
print(pred)
# Out:
# Enter Insulin: 110
# Enter Mass: 50
# Enter Age: 50
# ['tested_positive']
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(

# %%
from sklearn.tree import plot_tree

# %%
plot_tree(DT)
# Out:
# [Text(0.408959996371553, 0.9861111111111112, 'x[2] <= 28.5\ngini = 0.454\nsamples = 768\nvalue = [500, 268]'),
#  Text(0.19013062409288825, 0.9583333333333334, 'x[1] <= 30.95\ngini = 0.312\nsamples = 367\nvalue = [296, 71]'),
#  Text(0.06894049346879536, 0.9305555555555556, 'x[2] <= 26.5\ngini = 0.095\nsamples = 181\nvalue = [172, 9]'),
#  Text(0.03918722786647315, 0.9027777777777778, 'x[1] <= 28.3\ngini = 0.062\nsamples = 155\nvalue = [150, 5]'),
#  Text(0.023222060957910014, 0.875, 'x[0] <= 48.5\ngini = 0.034\nsamples = 114\nvalue = [112, 2]'),
#  Text(0.01741654571843251, 0.8472222222222222, 'x[0] <= 46.5\ngini = 0.062\nsamples = 62\nvalue = [60, 2]'),
#  Text(0.011611030478955007, 0.8194444444444444, 'x[1] <= 25.5\ngini = 0.032\nsamples = 61\nvalue = [60, 1]'),
#  Text(0.005805515239477504, 0.7916666666666666, 'gini = 0.0\nsamples = 42\nvalue = [42, 0]'),
#  Text(0.01741654571843251, 0.7916666666666666, 'x[1] <= 25.8\ngini = 0.1\nsamples = 19\nvalue = [18, 1]'),
# ...

# %%
if pred == ['tested_positive']:
  print("You have diabetes, Maintain Proper Medication")
else:
  print("You can freely enjoy eating Sweets")
# Out:
# You can freely enjoy eating Sweets
