# %%
import pandas as pd

# %%
df=pd.read_csv('/content/diabetcsv (1).csv')

# %%
df
# Out:
#      preg  plas  pres  skin  insu  mass   pedi  age            class
# 0       6   148    72    35     0  33.6  0.627   50  tested_positive
# 1       1    85    66    29     0  26.6  0.351   31  tested_negative
# 2       8   183    64     0     0  23.3  0.672   32  tested_positive
# 3       1    89    66    23    94  28.1  0.167   21  tested_negative
# 4       0   137    40    35   168  43.1  2.288   33  tested_positive
# ..    ...   ...   ...   ...   ...   ...    ...  ...              ...
# 763    10   101    76    48   180  32.9  0.171   63  tested_negative
# 764     2   122    70    27     0  36.8  0.340   27  tested_negative
# 765     5   121    72    23   112  26.2  0.245   30  tested_negative
# 766     1   126    60     0     0  30.1  0.349   47  tested_positive
# 767     1    93    70    31     0  30.4  0.315   23  tested_negative
#
# [768 rows x 9 columns]

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
target=df["class"]
print(target)
# Out:
# 0      tested_positive
# 1      tested_negative
# 2      tested_positive
# 3      tested_negative
# 4      tested_positive
#             ...
# 763    tested_negative
# 764    tested_negative
# 765    tested_negative
# 766    tested_positive
# 767    tested_negative
# Name: class, Length: 768, dtype: object

# %%
feat_list=['insu','mass','age','skin','plas']
feat=df[feat_list]
print(feat)
# Out:
#      insu  mass  age  skin  plas
# 0       0  33.6   50    35   148
# 1       0  26.6   31    29    85
# 2       0  23.3   32     0   183
# 3      94  28.1   21    23    89
# 4     168  43.1   33    35   137
# ..    ...   ...  ...   ...   ...
# 763   180  32.9   63    48   101
# 764     0  36.8   27    27   122
# 765   112  26.2   30    23   121
# 766     0  30.1   47     0   126
# 767     0  30.4   23    31    93
#
# [768 rows x 5 columns]

# %%
model=RandomForestClassifier()
model.fit(feat,target)
# Out:
# RandomForestClassifier()

# %%
insu=int(input("Enter Insulin: "))
mass=int(input("Enter Mass: "))
age=int(input("Enter Age: "))
plas=int(input("Enter Plas: "))
skin=int(input("Enter Skin: "))
pred=model.predict([[insu,mass,age,plas,skin]])
print(pred)
# Out:
# Enter Insulin: 100
# Enter Mass: 50
# Enter Age: 50
# Enter Plas: 50
# Enter Skin: 50
# ['tested_negative']
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(

# %%
if pred == ['tested_positive']:
  print("You have diabetes, Maintain Proper Medication")
else:
  print("You can freely enjoy eating Sweets")
# Out:
# You can freely enjoy eating Sweets
